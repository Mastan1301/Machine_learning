# %% [markdown]
# # Image classification using CNN
# Classify each image as containing a cat or a dog. We use CNN algorithm since this is a computer-vision problem.
#
# ## Data pre-processing

# %%
import cv2
import numpy as np
import os
from random import shuffle
from tqdm import tqdm

# %%
TRAIN_DIR = '../data/cats_vs_dogs/train/train/'
TEST_DIR = '../data/cats_vs_dogs/test/test/'
IMG_SIZE = 50
LR = 1e-3
n_epochs=5

MODEL_NAME = 'dogsvscats-{}-{}.model'.format(LR, '2conv-basic')

# %%
def label_image(img):
    # Take the first three letters
    word_label = img.split('.')[-3]
    if word_label == 'cat':
        return [1, 0]
    elif word_label == 'dog':
        return [0, 1]
    
def create_train_data():
    train_data = []
    for img in tqdm(os.listdir(TRAIN_DIR)):
        label = label_image(img)
        path = os.path.join(TRAIN_DIR, img)
        img = cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), (IMG_SIZE, IMG_SIZE))
        train_data.append([np.array(img), np.array(label)])
    
    shuffle(train_data)
    train_data = np.array(train_data)
    np.save('../data/cats_vs_dogs/train_data.npy', train_data)
    return train_data

# Process the Kaggle test data
def process_test_data():
    test_data = []
    for img in tqdm(os.listdir(TEST_DIR)):
        img_num = img.split('.')[0]
        path = os.path.join(TEST_DIR, img)
        img = cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), (IMG_SIZE, IMG_SIZE))
        test_data.append([np.array(img), np.array(img_num)])
    
    test_data = np.array(test_data)
    np.save('../data/cats_vs_dogs/test_data.npy', test_data)
    return test_data

# %%
# train_data = create_train_data()
# if you already have train data:
train_data = np.load('../data/cats_vs_dogs/train_data.npy', allow_pickle=True)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 25000/25000 [00:28<00:00, 883.69it/s]
# C:\Users\shaik\AppData\Local\Temp\ipykernel_14108\70842323.py:18: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   train_data = np.array(train_data)

# %%
print(train_data.shape)
print(train_data[0])
# Out:
# (25000, 2)
# [array([[167, 189, 154, ..., 161, 171, 167],
#         [168, 165, 171, ..., 156, 164, 170],
#         [167, 167, 169, ..., 167, 164, 165],
#         ...,
#         [109, 110, 110, ..., 153, 144, 146],
#         [107, 108, 109, ..., 146, 151, 179],
#         [106, 106, 106, ..., 154, 146, 152]], dtype=uint8) array([1, 0])]

# %%
X = np.array([i[0] for i in train_data]).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
y = np.array([i[1] for i in train_data])

# %%
validation_split = 0.2
validation_size = int(validation_split * len(X))
train_x, train_y = X[:-validation_size], y[:-validation_size]
val_x, val_y = X[-validation_size:], y[-validation_size:]

# %%
print(train_y.shape)
# Out:
# (20000, 2)

# %% [markdown]
# ## Define and train the model

# %%
import tensorflow as tf
import datetime

# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
model = tf.keras.models.Sequential([
            tf.keras.layers.InputLayer(input_shape=(IMG_SIZE, IMG_SIZE, 1)),
            
            tf.keras.layers.Conv2D(100, kernel_size=(3, 3), activation='relu'),
            tf.keras.layers.MaxPooling2D(pool_size = (2, 2)),
            tf.keras.layers.Dropout(0.2),
    
            tf.keras.layers.Conv2D(80, kernel_size=(3, 3), activation='relu'),
            tf.keras.layers.MaxPooling2D(pool_size = (2, 2)),
            tf.keras.layers.Dropout(0.2),
    
            tf.keras.layers.Conv2D(60, kernel_size=(3, 3), activation='relu'),
            tf.keras.layers.MaxPooling2D(pool_size = (2, 2)),
            tf.keras.layers.Dropout(0.2),
    
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(20, activation='relu'),
            tf.keras.layers.Dense(2, activation='softmax'),
        ])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(LR),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy()],
)

# %%
log_dir = "./logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
model.fit(
    x=train_x,
    y=train_y,
    epochs=3,
    validation_data=(val_x, val_y),
    callbacks=[tensorboard_callback],
)
# Out:
# Epoch 1/3
# 625/625 [==============================] - 56s 88ms/step - loss: 0.6935 - categorical_accuracy: 0.4949 - val_loss: 0.6931 - val_categorical_accuracy: 0.5062
# Epoch 2/3
# 625/625 [==============================] - 58s 93ms/step - loss: 0.6969 - categorical_accuracy: 0.4960 - val_loss: 0.6931 - val_categorical_accuracy: 0.5062
# Epoch 3/3
# 625/625 [==============================] - 56s 90ms/step - loss: 0.6933 - categorical_accuracy: 0.4963 - val_loss: 0.6932 - val_categorical_accuracy: 0.4938

# %% [markdown]
# ## Testing the model

# %%
import matplotlib.pyplot as plt

# %%
test_data = process_test_data()
# if you already have it
# test_data = np.load('../data/cats_vs_dogs/test_data.npy', allow_pickle=True)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 12500/12500 [00:13<00:00, 924.08it/s]
# C:\Users\shaik\AppData\Local\Temp\ipykernel_14108\193150637.py:31: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   test_data = np.array(test_data)

# %%
print(test_data.shape)
print(test_data[0][0])
# Out:
# (12500, 2)
# [[ 53  59  65 ...  95 102 121]
#  [ 45  59  64 ...  78  95 117]
#  [ 61  66  62 ... 106 100 101]
#  ...
#  [167 174 175 ... 150  95 145]
#  [193 191 194 ... 130  89  99]
#  [187 193 185 ... 120  73 115]]

# %%
fig = plt.figure()

for num, data in enumerate(test_data[:12]):
    # cat: [1, 0], dog: [0, 1]
    img_num = data[1]
    img_data = data[0]
    
    y = fig.add_subplot(3, 4, num + 1)
    original = img_data
    data = img_data.reshape(IMG_SIZE, IMG_SIZE, 1)
    
    # print([data].shape)
    model_out = model.predict(np.array([data]))[0]
    
    if np.argmax(model_out) == 1:
        str_label = 'Dog'
    else:
        str_label= 'Cat'
        
    y.imshow(original, cmap='gray')
    plt.title(str_label)
    y.axes.get_xaxis().set_visible(False)
    y.axes.get_yaxis().set_visible(False)
    
plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 22ms/step

# %%
with open('../data/cats_vs_dogs/submission-file.csv', 'w') as f:
    f.write('id, label\n')

# %%
with open('../data/cats_vs_dogs/submission-file.csv', 'a') as f:
    for data in tqdm(test_data):
        img_num = data[1]
        img_data = data[0]
        original = img_data
        data = img_data.reshape(IMG_SIZE, IMG_SIZE, 1)
        model_out = model.predict(np.array([data]))[0]
        f.write('{},{}\n'.format(img_num, model_out))
# Out:
# ...
# 1/1 [==============================] - 0s 25ms/step
# ...
# ...
#  43%|█████████████████████████████████▏                                           | 5379/12500 [05:47<07:39, 15.50it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [114], in <cell line: 1>()
#       5 original = img_data
#       6 data = img_data.reshape(IMG_SIZE, IMG_SIZE, 1)
# ----> 7 model_out = model.predict(np.array([data]))[0]
#       8 f.write('{},{}\n'.format(img_num, model_out))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...
